# %% [markdown]
# <a href="https://colab.research.google.com/github/Ser3nade/myRepo/blob/main/otcotc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip -o /content/OTC-AI-BOT-v0.4 -d /content
# Out:
# Archive:  /content/OTC-AI-BOT-v0.4.zip
#    creating: /content/OTC-AI-BOT/
#   inflating: /content/OTC-AI-BOT/main.py
#   inflating: /content/OTC-AI-BOT/config.py
#    creating: /content/OTC-AI-BOT/inquiry/
#  extracting: /content/OTC-AI-BOT/inquiry/__init__.py
#  extracting: /content/OTC-AI-BOT/inquiry/store.py
#   inflating: /content/OTC-AI-BOT/inquiry/repository.py
#   inflating: /content/OTC-AI-BOT/inquiry/service.py
#   inflating: /content/OTC-AI-BOT/inquiry/model.py
#  extracting: /content/OTC-AI-BOT/requirements.txt
#    creating: /content/OTC-AI-BOT/core/
#  extracting: /content/OTC-AI-BOT/core/__init__.py
#   inflating: /content/OTC-AI-BOT/core/router.py
#    creating: /content/OTC-AI-BOT/trade_log/
#  extracting: /content/OTC-AI-BOT/trade_log/__init__.py
#  extracting: /content/OTC-AI-BOT/trade_log/sheet_selector.py
#  extracting: /content/OTC-AI-BOT/trade_log/logger.py
#  extracting: /content/OTC-AI-BOT/trade_log/client_resolver.py
#    creating: /content/OTC-AI-BOT/bot/
# ...

# %%
# !ls
# Out:
# OTC-AI-BOT  OTC-AI-BOT-v0.4.zip  sample_data

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/OTC-AI-BOT/.git/

# %%
# %cd /content/OTC-AI-BOT
# Out:
# /content/OTC-AI-BOT
